# %%
# Impor library yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Membaca data dari file Excel
data = pd.read_excel("E:\Bahan Statistika\IHSG.xlsx")
data
# Out:
#      Period     IHSG    USD  Ringgit     YEN
# 0         1  3409.17   9043  2952.33  110.16
# 1         2  3470.35   8818  2889.25  107.81
# 2         3  3678.67   8705  2874.83  104.67
# 3         4  3819.62   8563  2889.00  105.39
# 4         5  3836.97   8532  2831.73  104.60
# ..      ...      ...    ...      ...     ...
# 127     128  6150.30  14265  3429.91  129.62
# 128     129  6286.94  14310  3416.91  128.57
# 129     130  6591.35  14165  3419.02  124.22
# 130     131  6533.93  14320  3405.47  126.52
# 131     132  6581.48  14250  3418.91  123.79
#
# [132 rows x 5 columns]

# %%
# Membuat plot untuk melihat tren penjualan seiring waktu
plt.figure(figsize=(10, 5))
plt.plot(data['Period'], data['IHSG'], marker='o')
plt.title('Tren IHSG')
plt.xlabel('Period')
plt.ylabel('IHSG')
plt.xticks(rotation=45)
plt.show()

# %%
# Membuat model regresi linier untuk memprediksi pendapatan berdasarkan produk terjual
model = LinearRegression()
X = data[['USD']]
y = data['IHSG']
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Menampilkan koefisien regresi
print("Koefisien Regresi:", model.coef_[0])
# Out:
# Koefisien Regresi: 0.3214206183869235

# %%
# Prediksi pendapatan untuk 200 produk terjual
USD_prediksi = 15000
IHSG_prediksi = model.predict([[USD_prediksi]])
print("Prediksi IHSG jika nilai 1 USD adalah 15000:", IHSG_prediksi[0])
# Out:
# Prediksi IHSG jika nilai 1 USD adalah 15000: 5965.869616561491
# D:\Program Statistika Rafif\anaconda\New folder\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
